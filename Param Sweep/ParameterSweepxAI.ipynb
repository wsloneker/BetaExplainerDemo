# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
base = pd.read_csv('data/baseResultsOverAlphaBeta.csv')
base['Dataset'] = 'SG-BASE'
base['Dataset Num'] = 0
hetero = pd.read_csv('data/heteroResultsOverAlphaBeta.csv')
hetero['Dataset'] = 'SG-HETEROPHILIC'
hetero['Dataset Num'] = 1
unfair = pd.read_csv('data/unfairResultsOverAlphaBeta.csv')
unfair['Dataset'] = 'SG-UNFAIR'
unfair['Dataset Num'] = 2
less = pd.read_csv('data/lessinformResultsOverAlphaBeta.csv')
less['Dataset'] = 'SG-LESSINFORM'
less['Dataset Num'] = 3
more = pd.read_csv('data/moreinformResultsOverAlphaBeta.csv')
more['Dataset'] = 'SG-MOREINFORM'
more['Dataset Num'] = 4
lst = [base, hetero, unfair, less, more]
df = pd.concat(lst)
df.head()
# Out:
#    Unnamed: 0    lr  alpha  beta  best acc  best prec  best rec   best f1  \
# 0           0  0.05    0.8   0.1  0.777778        1.0     0.875  0.777778
# 1           1  0.05    0.8   0.2  0.777778        1.0     0.875  0.777778
# 2           2  0.05    0.8   0.3  0.777778        1.0     0.875  0.777778
# 3           3  0.05    0.8   0.4  0.777778        1.0     0.875  0.777778
# 4           4  0.05    0.8   0.5  0.777778        1.0     0.875  0.777778
#
#      best faith  avg certainty what is og  Dataset  Dataset Num
# 0 -1.190000e-07         0.9075   og alpha  SG-BASE            0
# 1 -1.190000e-07         0.8023   og alpha  SG-BASE            0
# 2 -1.190000e-07         0.7071   og alpha  SG-BASE            0
# 3 -1.190000e-07         0.6441   og alpha  SG-BASE            0
# 4 -1.190000e-07         0.6003   og alpha  SG-BASE            0

# %%
alpha_consist = df[df['what is og'] == 'og alpha']
beta_consist = df[df['what is og'] == 'og beta']

# %%
curr = alpha_consist[alpha_consist['Dataset'] == 'SG-BASE']
plt.scatter(list(curr['beta']), list(curr['best acc']), color='#5d0379', marker='o', label='Best Accuracy')
plt.scatter(list(curr['beta']), list(curr['best f1']), color='#bb87cc', marker='o', label='Best F1 Score')
plt.scatter(list(curr['beta']), list(curr['best faith']), color='#046d1d', marker='v', label='Best Unfaithfulness')
plt.title('Beta Parameter Sweep Over Consistant Alpha Parameter for SG-BASE')
plt.xlabel('Beta')
plt.ylabel('Results')
plt.legend()

# %%
curr = alpha_consist[alpha_consist['Dataset'] == 'SG-HETEROPHILIC']
plt.scatter(list(curr['beta']), list(curr['best acc']), color='#5d0379', marker='o', label='Best Accuracy')
plt.scatter(list(curr['beta']), list(curr['best f1']), color='#bb87cc', marker='o', label='Best F1 Score')
plt.scatter(list(curr['beta']), list(curr['best faith']), color='#046d1d', marker='v', label='Best Unfaithfulness')
plt.title('Beta Parameter Sweep Over Consistant Alpha Parameter for SG-HETEROPHILIC')
plt.xlabel('Beta')
plt.ylabel('Results')
plt.legend()

# %%
curr = alpha_consist[alpha_consist['Dataset'] == 'SG-UNFAIR']
plt.scatter(list(curr['beta']), list(curr['best acc']), color='#5d0379', marker='o', label='Best Accuracy')
plt.scatter(list(curr['beta']), list(curr['best f1']), color='#bb87cc', marker='o', label='Best F1 Score')
plt.scatter(list(curr['beta']), list(curr['best faith']), color='#046d1d', marker='v', label='Best Unfaithfulness')
plt.title('Beta Parameter Sweep Over Consistant Alpha Parameter for SG-UNFAIR')
plt.xlabel('Beta')
plt.ylabel('Results')
plt.legend()

# %%
curr = alpha_consist[alpha_consist['Dataset'] == 'SG-MOREINFORM']
plt.scatter(list(curr['beta']), list(curr['best acc']), color='#5d0379', marker='o', label='Best Accuracy')
plt.scatter(list(curr['beta']), list(curr['best f1']), color='#bb87cc', marker='o', label='Best F1 Score')
plt.scatter(list(curr['beta']), list(curr['best faith']), color='#046d1d', marker='v', label='Best Unfaithfulness')
plt.title('Beta Parameter Sweep Over Consistant Alpha Parameter for SG-MOREINFORM')
plt.xlabel('Beta')
plt.ylabel('Results')
plt.legend()

# %%
curr = alpha_consist[alpha_consist['Dataset'] == 'SG-LESSINFORM']
plt.scatter(list(curr['beta']), list(curr['best acc']), color='#5d0379', marker='o', label='Best Accuracy')
plt.scatter(list(curr['beta']), list(curr['best f1']), color='#bb87cc', marker='o', label='Best F1 Score')
plt.scatter(list(curr['beta']), list(curr['best faith']), color='#046d1d', marker='v', label='Best Unfaithfulness')
plt.title('Beta Parameter Sweep Over Consistant Alpha Parameter for SG-LESSINFORM')
plt.xlabel('Beta')
plt.ylabel('Results')
plt.legend()

# %%
curr = beta_consist[beta_consist['Dataset'] == 'SG-BASE']
plt.scatter(list(curr['alpha']), list(curr['best acc']), color='#5d0379', marker='o', label='Best Accuracy')
plt.scatter(list(curr['alpha']), list(curr['best f1']), color='#bb87cc', marker='o', label='Best F1 Score')
plt.scatter(list(curr['alpha']), list(curr['best faith']), color='#046d1d', marker='v', label='Best Unfaithfulness')
plt.title('Alpha Parameter Sweep Over Consistant Beta Parameter for SG-BASE')
plt.xlabel('Alpha')
plt.ylabel('Results')
plt.legend()

# %%
curr = beta_consist[beta_consist['Dataset'] == 'SG-UNFAIR']
plt.scatter(list(curr['alpha']), list(curr['best acc']), color='#5d0379', marker='o', label='Best Accuracy')
plt.scatter(list(curr['alpha']), list(curr['best f1']), color='#bb87cc', marker='o', label='Best F1 Score')
plt.scatter(list(curr['alpha']), list(curr['best faith']), color='#046d1d', marker='v', label='Best Unfaithfulness')
plt.title('Alpha Parameter Sweep Over Consistant Beta Parameter for SG-UNFAIR')
plt.xlabel('Alpha')
plt.ylabel('Results')
plt.legend()

# %%
curr = beta_consist[beta_consist['Dataset'] == 'SG-HETEROPHILIC']
plt.scatter(list(curr['alpha']), list(curr['best acc']), color='#5d0379', marker='o', label='Best Accuracy')
plt.scatter(list(curr['alpha']), list(curr['best f1']), color='#bb87cc', marker='o', label='Best F1 Score')
plt.scatter(list(curr['alpha']), list(curr['best faith']), color='#046d1d', marker='v', label='Best Unfaithfulness')
plt.title('Alpha Parameter Sweep Over Consistant Beta Parameter for SG-HETEROPHILIC')
plt.xlabel('Alpha')
plt.ylabel('Results')
plt.legend()

# %%
curr = beta_consist[beta_consist['Dataset'] == 'SG-LESSINFORM']
plt.scatter(list(curr['alpha']), list(curr['best acc']), color='#5d0379', marker='o', label='Best Accuracy')
plt.scatter(list(curr['alpha']), list(curr['best f1']), color='#bb87cc', marker='o', label='Best F1 Score')
plt.scatter(list(curr['alpha']), list(curr['best faith']), color='#046d1d', marker='v', label='Best Unfaithfulness')
plt.title('Alpha Parameter Sweep Over Consistant Beta Parameter for SG-LESSINFORM')
plt.xlabel('Alpha')
plt.ylabel('Results')
plt.legend()

# %%
curr = beta_consist[beta_consist['Dataset'] == 'SG-MOREINFORM']
plt.scatter(list(curr['alpha']), list(curr['best acc']), color='#5d0379', marker='o', label='Best Accuracy')
plt.scatter(list(curr['alpha']), list(curr['best f1']), color='#bb87cc', marker='o', label='Best F1 Score')
plt.scatter(list(curr['alpha']), list(curr['best faith']), color='#046d1d', marker='v', label='Best Unfaithfulness')
plt.title('Alpha Parameter Sweep Over Consistant Beta Parameter for SG-LESSINFORM')
plt.xlabel('Alpha')
plt.ylabel('Results')
plt.legend()

# %%
df.head()
# Out:
#    Unnamed: 0    lr  alpha  beta  best acc  best prec  best rec   best f1  \
# 0           0  0.05    0.8   0.1  0.777778        1.0     0.875  0.777778
# 1           1  0.05    0.8   0.2  0.777778        1.0     0.875  0.777778
# 2           2  0.05    0.8   0.3  0.777778        1.0     0.875  0.777778
# 3           3  0.05    0.8   0.4  0.777778        1.0     0.875  0.777778
# 4           4  0.05    0.8   0.5  0.777778        1.0     0.875  0.777778
#
#      best faith  avg certainty what is og  Dataset  Dataset Num
# 0 -1.190000e-07         0.9075   og alpha  SG-BASE            0
# 1 -1.190000e-07         0.8023   og alpha  SG-BASE            0
# 2 -1.190000e-07         0.7071   og alpha  SG-BASE            0
# 3 -1.190000e-07         0.6441   og alpha  SG-BASE            0
# 4 -1.190000e-07         0.6003   og alpha  SG-BASE            0

# %%
curr = df[df['Dataset'] == 'SG-BASE']
plt.scatter(list(curr['avg certainty']), list(curr['best faith']), marker='o', label='Best Unfaithfulness')
plt.title('Effect of Average Certainty on Best Unfaithfulness for Various Alpha & Beta Values on SG-BASE')
plt.xlabel('Average Certainty')
plt.ylabel('Best Unfaithfulness')
plt.legend()

# %%
curr = df[df['Dataset'] == 'SG-HETEROPHILIC']
plt.scatter(list(curr['avg certainty']), list(curr['best faith']), marker='o', label='Best Unfaithfulness')
plt.title('Effect of Average Certainty on Best Unfaithfulness for Various Alpha & Beta Values on SG-HETEROPHILIC')
plt.xlabel('Average Certainty')
plt.ylabel('Best Unfaithfulness')
plt.legend()

# %%
curr = df[df['Dataset'] == 'SG-UNFAIR']
plt.scatter(list(curr['avg certainty']), list(curr['best faith']), marker='o', label='Best Unfaithfulness')
plt.title('Effect of Average Certainty on Best Unfaithfulness for Various Alpha & Beta Values on SG-UNFAIR')
plt.xlabel('Average Certainty')
plt.ylabel('Best Unfaithfulness')
plt.legend()

# %%
curr = df[df['Dataset'] == 'SG-LESSINFORM']
plt.scatter(list(curr['avg certainty']), list(curr['best faith']), marker='o', label='Best Unfaithfulness')
plt.title('Effect of Average Certainty on Best Unfaithfulness for Various Alpha & Beta Values on SG-LESSINFORM')
plt.xlabel('Average Certainty')
plt.ylabel('Best Unfaithfulness')
plt.legend()

# %%
curr = df[df['Dataset'] == 'SG-MOREINFORM']
plt.scatter(list(curr['avg certainty']), list(curr['best faith']), marker='o', label='Best Unfaithfulness')
plt.title('Effect of Average Certainty on Best Unfaithfulness for Various Alpha & Beta Values on SG-MOREINFORM')
plt.xlabel('Average Certainty')
plt.ylabel('Best Unfaithfulness')
plt.legend()
